# %%
# standard library
from pathlib import Path
from typing import Iterable, Any

# third party library
import csv

# local library
from constants import SCRIPT_DIR
from accessor import Csv
from gpu import GPU

# %%
filepath = SCRIPT_DIR / "results.csv"
results = Csv(filepath).read()[1:]

# %%
results
# Out:
# [('Intel Arc A750 8G 顯示卡',
#   'Intel Arc A750 8G 顯示卡 pci-e 4.0 8gb gddr6 dp hdmi',
#   '6990'),
#  ('ZOTAC 索泰 GAMING GeForce GTX 1650 AMP Core GDDR6 顯示卡',
#   '基於嶄新的 nvidia turing™ gpu 架構打造 配備快速 gddr6 記憶體 預設超頻加速 體積小巧 支援 4k 影像 70 毫米雙風扇 firestorm 程式',
#   '3990'),
#  ('華碩 TUF-GTX1660S-O6G-GAMING 顯示卡',
#   'nvidia geforce gtx 1660 super 6gb gddr6 boost 1815 mhz',
#   '6188'),
#  ('微星 GeForce GTX 1650 D6 VENTUS XS OC V3 顯示卡',
#   '記憶體 ：4gb gddr6 核心時脈 ：1620 mhz 記憶體介面：128-bit',
#   '4390'),
#  ('微星 GeForce GT 1030 2GD4 LP OC 顯示卡',
#   '微星 GeForce GT 1030 2GD4 LP OC 顯示卡 ◆ 顯示晶片 ：nvidia geforce gtx 1030 ◆ 記憶體 ：2gb ddr4 ◆ cuda數 ：384 ◆ 核心時脈 ：1189',
#   '3090'),
#  ('華碩 GT730-SL-2GD5-BRK 顯示卡',
#   '華碩 GT730-SL-2GD5-BRK 顯示卡 ◆ 顯示晶片 ：nvidia® geforce gt 730 ◆ 記憶體 ：2gb gddr5 ◆ cuda數 ：384 ◆ 核心時脈 ：902 mhz ◆ 記憶體',
#   '2690'),
#  ('華碩 GT1030-SL-2G-BRK 顯示卡',
#   '華碩 GT1030-SL-2G-BRK 顯示卡 ◆ 顯示晶片 ：nvidia geforce gt 1030 ◆ 記憶體 ：2gb gddr5 ◆ cuda數 ：384 ◆ 核心時脈 ：1266 mhz ◆ 記',
#   '2890'),
# ...

# %%
# records: list[GPU] = []
# for result in results:
#     for title, desc, price in result:
#         records.append(GPU.parse(title, desc, int(price)))

# %%
# Out:
# track
# OEM.ASUS
# ValueError，因為 "ASUS" 不是 OEM 定義的列舉 value
# <class '__main__.NewClass'>
# <enum 'OEM'>
# ASUS
# Asus
# MSI
# Msi
# NVIDIA
# 1
# AMD
# 2
# ['NVIDIA', 'AMD', 'INTEL']
# [1, 2, 3]
